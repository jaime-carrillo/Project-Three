# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Read in csv (already transformed)
hosp_df = pd.read_csv('..//..//data/hospitals/All_Hospitals.csv')

# Drop columns not need for modeling
df = hosp_df.drop(['Description', 'FAC_NO', 'FAC_NAME','FAC_STR_ADDR','FAC_CITY','FAC_PHONE','FAC_ADMIN_NAME','FAC_OPERATED_THIS_YR','FAC_OP_PER_BEGIN_DT','FAC_OP_PER_END_DT','FAC_PAR_CORP_NAME','FAC_PAR_CORP_BUS_ADDR','FAC_PAR_CORP_CITY','FAC_PAR_CORP_STATE','REPT_PREP_NAME','SUBMITTED_DT','REV_REPT_PREP_NAME','REVISED_DT','CORRECTED_DT','LICENSE_NO','LICENSE_EFF_DATE','LICENSE_EXP_DATE','LICENSE_STATUS','FACILITY_LEVEL','ASSEMBLY_DIST','SENATE_DIST','CONGRESS_DIST','CENS_TRACT','MED_SVC_STUDY_AREA','LA_COUNTY_SVC_PLAN_AREA','COUNTY'], axis=1)
# ,'RURAL_HEALTH_CLINIC']

# Format Categorical Data
df.TEACH_HOSP = df.TEACH_HOSP != "No"
df.TEACH_RURAL = df.TEACH_RURAL != "No"
df.TRAUMA_CTR = df.TRAUMA_CTR != 0
df.HEALTH_SVC_AREA = df.HEALTH_SVC_AREA.str[:2]
df.LIC_CAT = df.LIC_CAT == "General Acute Care Hospital"
df.LICEE_TOC = df.LICEE_TOC == "Non-Profit Corporation (including church-related)"
df.PRIN_SERVICE_TYPE = df.PRIN_SERVICE_TYPE == "General Medical / Surgical"
df.FAC_ACQUIRE_EQUIP_OVER_500K = df.FAC_ACQUIRE_EQUIP_OVER_500K != "No"
df.OFFER_ALTERNATE_BIRTH_PROG = df.OFFER_ALTERNATE_BIRTH_PROG != "No"
df.LIC_CARDIOLOGY_CARDIOVASCULAR_SURG_SERVICES = df.LIC_CARDIOLOGY_CARDIOVASCULAR_SURG_SERVICES != 0
df.OFFER_AMBULATORY_SURG_PROG = df.OFFER_AMBULATORY_SURG_PROG != "No"
df.LIC_ED_LEV_END = df.LIC_ED_LEV_END != 0
df.EMSA_TRAUMA_DESIGNATION_PEDIATRIC = df.EMSA_TRAUMA_DESIGNATION_PEDIATRIC != 0
df.EMER_DEPT_AMBULANCE_DIVERSION_HOURS = df.EMER_DEPT_AMBULANCE_DIVERSION_HOURS != "No"
df.LIC_ED_LEV_BEGIN = df.LIC_ED_LEV_BEGIN != 0
df.EMSA_TRAUMA_DESIGNATION = df.EMSA_TRAUMA_DESIGNATION != 0
df.OUTPATIENT_PALLIATIVE_CARE_SERV_OFFERED = df.OUTPATIENT_PALLIATIVE_CARE_SERV_OFFERED != 0
df.INPATIENT_PALLIATIVE_CARE_PROG_OFFERED = df.INPATIENT_PALLIATIVE_CARE_PROG_OFFERED != 0
df.INPATIENT_HOSPICE_PROG_OFFERED = df.INPATIENT_HOSPICE_PROG_OFFERED != 0
df.SHORT_DOYLE_SERVICES_OFFERED = df.SHORT_DOYLE_SERVICES_OFFERED != 0


# df.PRIMARY_NON_ENGLISH_LANG = df.PRIMARY_NON_ENGLISH_LANG == "Spanish"
df.replace(True, 1, inplace=True)

# Drop final coloumns
df.drop(df.iloc[:, 267:323], inplace=True, axis=1)

# Fill in all blanks with 0 (for deep learning)
df = df.fillna(0)

df.head()
# Out:
#    FAC_ZIP  FAC_PAR_CORP_ZIP  TRAUMA_CTR  TEACH_HOSP  TEACH_RURAL   LONGITUDE  \
# 0  94501.0             94602         1.0         0.0          0.0 -122.253991
# 1  94705.0             95833         1.0         0.0          0.0 -122.257430
# 2  94609.0                 0         1.0         0.0          0.0 -122.267470
# 3  94578.0             94602         1.0         0.0          0.0 -122.118190
# 4  94704.0             95833         1.0         0.0          0.0 -122.269840
#
#    LATITUDE HEALTH_SVC_AREA  LIC_CAT  LICEE_TOC  ...  \
# 0  37.76266              05      1.0        0.0  ...
# 1  37.85645              05      1.0        1.0  ...
# 2  37.83722              05      1.0        1.0  ...
# 3  37.70648              05      1.0        0.0  ...
# 4  37.86373              05      1.0        1.0  ...
#
#    CARD_CATH_PED_IP_THER_VST  CARD_CATH_PED_OP_THER_VST  \
# 0                          0                          0
# 1                          0                          0
# 2                         22                         35
# 3                          0                          0
# 4                          0                          0
#
#    CARDIAC_CATHETERIZATION_ADULT_INPAT_THERAPEUTIC_VISITS  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  0
# 4                                                  0
#
#    CARDIAC_CATHETERIZATION_ADULT_OUTPAT_THERAPEUTIC_VISITS  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    CARDIAC_CATHETERIZATION_THERAPEUTIC_VISITS_TOT  INPATIENT_AVG_PER_SURGERY  \
# 0                                               0                      105.0
# 1                                               0                      127.6
# 2                                              60                      137.4
# 3                                               0                        0.0
# 4                                               0                        0.0
#
#    OUTPATIENT_AVG_PER_SURGERY  FAC_ACQUIRE_EQUIP_OVER_500K    Target  Label
# 0                        75.2                          1.0  0.059835    1.0
# 1                        75.8                          1.0  0.012884    0.0
# 2                        70.8                          0.0  0.000000    0.0
# 3                         0.0                          0.0  0.000000    0.0
# 4                         0.0                          0.0  0.000000    0.0
#
# [5 rows x 269 columns]

# %%
# Set features. This will also be used as your x values.
selected_features = df.iloc[:, 0:267]
print(selected_features.shape)
# Out:
# (478, 267)

# %%
selected_features
# Out:
#      FAC_ZIP  FAC_PAR_CORP_ZIP  TRAUMA_CTR  TEACH_HOSP  TEACH_RURAL  \
# 0    94501.0             94602         1.0         0.0          0.0
# 1    94705.0             95833         1.0         0.0          0.0
# 2    94609.0                 0         1.0         0.0          0.0
# 3    94578.0             94602         1.0         0.0          0.0
# 4    94704.0             95833         1.0         0.0          0.0
# ..       ...               ...         ...         ...          ...
# 473  95901.0             95991         1.0         0.0          0.0
# 474  93703.0             93611         1.0         0.0          0.0
# 475  93940.0             93940         1.0         0.0          0.0
# 476  95023.0             95023         1.0         0.0          0.0
# 477      0.0                 0         1.0         1.0          1.0
#
#       LONGITUDE   LATITUDE HEALTH_SVC_AREA  LIC_CAT  LICEE_TOC  ...  \
# 0   -122.253991  37.762660              05      1.0        0.0  ...
# 1   -122.257430  37.856450              05      1.0        1.0  ...
# 2   -122.267470  37.837220              05      1.0        1.0  ...
# 3   -122.118190  37.706480              05      1.0        0.0  ...
# 4   -122.269840  37.863730              05      1.0        1.0  ...
# ..          ...        ...             ...      ...        ...  ...
# 473 -121.593602  39.138805              02      1.0        1.0  ...
# 474 -119.779521  36.778140              09      1.0        1.0  ...
# 475 -121.892428  36.580786              08      1.0        1.0  ...
# 476 -121.386700  36.835140              08      1.0        0.0  ...
# 477    0.000000   0.000000               0      0.0        0.0  ...
#
#      CARDIOVASCULAR_SURG_OPER_ADULT_BYPASS_NOT_USED  \
# 0                                                 0
# 1                                                 0
# 2                                                 3
# 3                                                 0
# 4                                                 0
# ..                                              ...
# 473                                              89
# 474                                               0
# 475                                               0
# 476                                               0
# 477                                               0
#
#      CARDIOVASCULAR_SURG_OPER_BYPASS_NOT_USED_TOT  CARD_CATH_PED_IP_THER_VST  \
# 0                                               0                          0
# 1                                               0                          0
# 2                                              34                         22
# 3                                               0                          0
# 4                                               0                          0
# ..                                            ...                        ...
# 473                                            89                          0
# 474                                             0                          0
# 475                                             0                          0
# 476                                             0                          0
# 477                                             0                          0
#
#      CARD_CATH_PED_OP_THER_VST  \
# 0                            0
# 1                            0
# 2                           35
# 3                            0
# 4                            0
# ..                         ...
# 473                          0
# 474                          0
# 475                          0
# 476                          0
# 477                          0
#
#      CARDIAC_CATHETERIZATION_ADULT_INPAT_THERAPEUTIC_VISITS  \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 473                                                369
# 474                                                  0
# 475                                                  0
# 476                                                  0
# 477                                                  0
#
#      CARDIAC_CATHETERIZATION_ADULT_OUTPAT_THERAPEUTIC_VISITS  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 473                                                358
# 474                                                  0
# 475                                                  0
# 476                                                  0
# 477                                                  0
#
#      CARDIAC_CATHETERIZATION_THERAPEUTIC_VISITS_TOT  \
# 0                                                 0
# 1                                                 0
# 2                                                60
# 3                                                 0
# 4                                                 0
# ..                                              ...
# 473                                             727
# 474                                               0
# 475                                               0
# 476                                               0
# 477                                               0
#
#      INPATIENT_AVG_PER_SURGERY  OUTPATIENT_AVG_PER_SURGERY  \
# 0                        105.0                        75.2
# 1                        127.6                        75.8
# 2                        137.4                        70.8
# 3                          0.0                         0.0
# 4                          0.0                         0.0
# ..                         ...                         ...
# 473                      145.5                        84.8
# 474                        0.0                         0.0
# 475                        0.0                         0.0
# 476                        0.0                         0.0
# 477                        0.0                         0.0
#
#      FAC_ACQUIRE_EQUIP_OVER_500K
# 0                            1.0
# 1                            1.0
# 2                            0.0
# 3                            0.0
# 4                            0.0
# ..                           ...
# 473                          0.0
# 474                          0.0
# 475                          0.0
# 476                          0.0
# 477                          1.0
#
# [478 rows x 267 columns]

# %%
X = selected_features
y = df["Label"]
# y = df["Target"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (478, 267) (478,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#      FAC_ZIP  FAC_PAR_CORP_ZIP  TRAUMA_CTR  TEACH_HOSP  TEACH_RURAL  \
# 234  92843.0                 0         1.0         0.0          0.0
# 247  92708.0             75202         1.0         0.0          0.0
# 333  92123.0             92123         1.0         0.0          0.0
# 132  91791.0             40202         1.0         0.0          0.0
# 94   90640.0             60640         1.0         0.0          0.0
#
#       LONGITUDE   LATITUDE HEALTH_SVC_AREA  LIC_CAT  LICEE_TOC  ...  \
# 234 -117.913032  33.774509              13      1.0        0.0  ...
# 247 -117.931590  33.716250              13      1.0        0.0  ...
# 333 -117.154900  32.800700              14      1.0        1.0  ...
# 132 -117.916690  34.085700              11      1.0        0.0  ...
# 94  -118.101320  34.016140              11      1.0        1.0  ...
#
#      CARDIOVASCULAR_SURG_OPER_ADULT_BYPASS_NOT_USED  \
# 234                                              10
# 247                                               0
# 333                                               0
# 132                                               0
# 94                                                0
#
#      CARDIOVASCULAR_SURG_OPER_BYPASS_NOT_USED_TOT  CARD_CATH_PED_IP_THER_VST  \
# 234                                            10                          0
# 247                                             0                          0
# 333                                             0                          0
# 132                                             0                          0
# 94                                              0                          0
#
#      CARD_CATH_PED_OP_THER_VST  \
# 234                          0
# 247                          0
# 333                          0
# 132                          0
# 94                           0
#
#      CARDIAC_CATHETERIZATION_ADULT_INPAT_THERAPEUTIC_VISITS  \
# 234                                                  0
# 247                                                  0
# 333                                                  0
# 132                                                  0
# 94                                                   0
#
#      CARDIAC_CATHETERIZATION_ADULT_OUTPAT_THERAPEUTIC_VISITS  \
# 234                                                  0
# 247                                                  0
# 333                                                  0
# 132                                                  0
# 94                                                   0
#
#      CARDIAC_CATHETERIZATION_THERAPEUTIC_VISITS_TOT  \
# 234                                               0
# 247                                               0
# 333                                               0
# 132                                               0
# 94                                                0
#
#      INPATIENT_AVG_PER_SURGERY  OUTPATIENT_AVG_PER_SURGERY  \
# 234                       81.2                        63.1
# 247                        0.0                         0.0
# 333                       51.0                        81.4
# 132                       18.3                         0.0
# 94                       110.6                        73.8
#
#      FAC_ACQUIRE_EQUIP_OVER_500K
# 234                          0.0
# 247                          0.0
# 333                          1.0
# 132                          0.0
# 94                           0.0
#
# [5 rows x 267 columns]

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the SVC Model
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.4022346368715084
# Testing Data Score: 0.475

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid2 = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid2.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.833, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.750, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.819, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.775, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.704, total=   0.0s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.833, total=   0.0s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.750, total=   0.0s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.819, total=   0.0s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.775, total=   0.0s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.704, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.833, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.750, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.819, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.775, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.704, total=   0.0s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.833, total=   0.0s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.750, total=   0.0s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.819, total=   0.0s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.775, total=   0.0s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.704, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.889, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.792, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.903, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.690, total=   0.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.761, total=   0.0s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.889, total=   0.0s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.792, total=   0.0s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.903, total=   0.0s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.690, total=   0.0s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.761, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.889, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.792, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.903, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.690, total=   0.0s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.761, total=   0.0s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.889, total=   0.0s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.792, total=   0.0s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.903, total=   0.0s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.690, total=   0.0s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.761, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.889, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.819, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.875, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.704, total=   0.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.761, total=   0.0s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.889, total=   0.0s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.819, total=   0.0s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.875, total=   0.0s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.704, total=   0.0s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.761, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.889, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.819, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.875, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.704, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.761, total=   0.0s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.889, total=   0.0s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.819, total=   0.0s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.875, total=   0.0s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.704, total=   0.0s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.761, total=   0.0s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.861, total=   0.0s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.819, total=   0.0s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.889, total=   0.0s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.676, total=   0.0s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.732, total=   0.0s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.861, total=   0.0s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.819, total=   0.0s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.889, total=   0.0s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.676, total=   0.0s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.732, total=   0.0s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.861, total=   0.0s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.819, total=   0.0s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.889, total=   0.0s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.676, total=   0.0s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.732, total=   0.0s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.861, total=   0.0s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.819, total=   0.0s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.889, total=   0.0s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.676, total=   0.0s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.732, total=   0.0s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    1.5s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 50],
#                          'gamma': [0.0001, 0.0005, 0.001, 0.005]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'C': 10, 'gamma': 0.0001}
# 0.8096244131455398

# %%
correlations_df = df[['FAC_ZIP','TEACH_HOSP','Target']].astype(float)

# %%
correlations = correlations_df.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot = True)
